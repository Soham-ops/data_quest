# %% [markdown]
# report 1

# %%
# %sql
SELECT * FROM rearc.rearc_dbt_schema.report_population_stats;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>mean_population</th><th>stddev_population</th></tr></thead><tbody><tr><td>3.22069808E8</td><td>4158441.040908095</td></tr></tbody></table></div>

# %% [markdown]
# report 2

# %%
# %sql
SELECT * FROM rearc.rearc_dbt_schema.report_best_year_per_series;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# report 3

# %%
# %sql
SELECT * FROM rearc.rearc_dbt_schema.report_3;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
